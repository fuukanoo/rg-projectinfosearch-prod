# %% [markdown]
# 'ファイルアップロード機能活用事例調査\n\nシステム設計・開発のプロセス全体をサポートするためにChatGPTを効果的に利用する方法を考えると、以下のようなファイルとプロンプトの組み合わせが有用です。\n\n\\### 1. システム要件定義\n\n\\*\\*アップロードするファイル例\\*\\*：\n\n\\- 要件定義書（機能要件、非機能要件のリストが含まれるファイル）\n\n\\- 現行システムのドキュメントやユーザーストーリー\n\n\\- 顧客とのヒアリング内容や仕様書\n\n\\*\\*プロンプト例\\*\\*：\n\n\\- 「この要件定義書の内容を要約して、主要な機能要件と非機能要件を分かりやすくリスト化してください。」\n\n\\- 「この要件定義から、追加するべき項目や不明確な箇所を指摘してください。」\n\n---\n\n\\### 2. 基本設計\n\n\\*\\*アップロードするファイル例\\*\\*：\n\n\\- システム構成図\n\n\\- 基本設計書（機能一覧やシステム全体の流れを示すドキュメント）\n\n\\*\\*プロンプト例\\*\\*：\n\n\\- 「この基本設計書をもとに、システム構成図に追加するべき要素を提案してください。」\n\n\\- 「システムの基本設計に基づき、各コンポーネント間のインターフェース設計のベストプラクティスを教えてください。」\n\n---\n\n\\### 3. 詳細設計\n\n\\*\\*アップロードするファイル例\\*\\*：\n\n\\- 詳細設計書（データベース設計書、API仕様書、クラス図など）\n\n\\*\\*プロンプト例\\*\\*：\n\n\\- 「この詳細設計書から、重要なデータベーステーブルの設計に関するアドバイスをください。」\n\n\\- 「このAPI設計書をチェックして、セキュリティやパフォーマンスにおける改善提案をお願いします。」\n\n---\n\n\\### 4. テスト設計\n\n\\*\\*アップロードするファイル例\\*\\*：\n\n\\- テストケース一覧\n\n\\- テスト計画書\n\n\\*\\*プロンプト例\\*\\*：\n\n\\- 「このテストケース一覧から、不足しているテストシナリオを追加してください。」\n\n\\- 「システム要件定義とテストケースを比較し、抜け漏れを特定してください。」\n\n---\n\n\\### 5. システム開発\n\n\\*\\*アップロードするファイル例\\*\\*：\n\n\\- コードリポジトリのドキュメントやコードスニペット\n\n\\- 開発フローや進捗報告\n\n\\*\\*プロンプト例\\*\\*：\n\n\\- 「このコードスニペットに関してリファクタリングを提案してください。」\n\n\\- 「開発フローの効率化についてアドバイスをください。」\n\n---\n\n\\### 6. 保守運用\n\n\\*\\*アップロードするファイル例\\*\\*：\n\n\\- 障害対応履歴\n\n\\- システム監視ログ\n\n\\- サービス運用マニュアル\n\n\\*\\*プロンプト例\\*\\*：\n\n\\- 「このシステム監視ログを分析し、異常のパターンを特定してください。」\n\n\\- 「保守運用における改善点を見つけるため、この障害対応履歴を分析してください。」\n\n---\n\n\\### 注意点\n\n\\- ファイルに機密情報が含まれている場合、アップロード前に匿名化や必要な部分のみの抜粋を推奨します。\n\n\\- プロンプトには、具体的な目的（例：「効率化」「最適化」「パフォーマンス改善」など）を明示すると、さらに適切なアドバイスが得られやすくなります。\n\nこれらのファイルとプロンプトの組み合わせを活用することで、システム設計から運用まで一貫した支援を得られるでしょう。\n'

# %% [markdown]
# [Document(metadata={'Header 1': '入社連絡票(正社員)'}, page_content='【社保加入連絡票】シャホカニュウレンラクヒョウ  \n本人ホンニン  \n氏名シメイ  \n姓  \n名  \n性別セイベツ  \n姓(カナ)  \n名(カナ)  \n入社日ニュウシャビ  \n生年月日セイネンガッピ  \n住所ジュウショ  \n郵便番号ユウビンバンゴウ  \n都道府県トドウフケン  \n市区町村シクチョウソン  \n番地バンチ  \nマンション・アパート名メイ  \n市区町村(カナ)シクチョウソン  \n緊急連絡先①キンキュウレンラクサキ  \n氏名シメイ  \n姓  \n名  \n性別セイベツ  \n姓(カナ)  \n名(カナ)  \n住所ジュウショ  \n郵便番号ユウビンバンゴウ  \n都道府県トドウフケン  \n市区町村シクチョウソン  \n番地バンチ  \nマンション・アパート名メイ  \n市区町村(カナ)シクチョウソン  \n電話番号デンワバンゴウ  \nメールアドレス  \n緊急連絡先②キンキュウレンラクサキ  \n氏名シメイ  \n姓  \n名  \n性別セイベツ  \n姓(カナ)  \n名(カナ)  \n住所ジュウショ  \n郵便番号ユウビンバンゴウ  \n都道府県トドウフケン  \n市区町村シクチョウソン  \n番地バンチ  \nマンション・アパート名メイ  \n市区町村(カナ)シクチョウソン  \n電話番号デンワバンゴウ  \nメールアドレス  \n社員区分シャインクブン  \n正社員  \n社員コードシャイン  \n電話番号デンワバンゴウ  \n※xxx-xxxx-xxxxの形式でご入力くださいケイシキニュウリョク  \nメールアドレス  \n基礎年金番号キソネンキンバンゴウ  \n※xxxxxxxxxx(ハイフンなし)の形式でご入力くださいケイシキニュウリョク  \n雇用保険番号コヨウホケンバンゴウ  \n※xxxx-xxxxxx-xの形式でご入力くださいケイシキニュウリョク  \n雇用保険番号が不明の場合、前職の社名をご記載ください。コヨウホケンバンゴウフメイバアイゼンショクシャメイキサイ  \nマイナンバー  \n給与キュウヨ  \n基本給キホンキュウ  \n時間給  \n交通費コウツウヒ  \n都度払い  \n他に手当あればご記入くださいタテアテキニュウ  \n契約期間ケイヤクキカン  \n契約期間の定めケイヤクキカンサダ  \nなし  \n有期の場合の期間ユウキバアイキカン  \n～  \n所定労働時間ショテイロウドウジカン  \n1日ニチ  \n8  \n時間ジカン  \n分フン  \n1週間シュウカン  \n40  \n時間ジカン  \n分フン  \n所定労働日数ショテイロウドウニッスウ  \n1ヵ月あたりゲツ  \n日ニチ  \n※特に定めがない場合、ご記載不要です。トクサダバアイキサイフヨウ  \n振込口座フリコミコウザ  \n銀行名ギンコウメイ  \n支店名シテンメイ  \n口座番号コウザバンゴウ  \n主たる給与の  \n受け取り先に該当シュキュウヨウトサキガイトウ  \n選択  \n⇒該当する場合、扶養控除等異動申告書を共有くださいガイトウバアイフヨウコウジョナドイドウシンコクショキョウユウ  \n家族情報カゾクジョウホウ  \n1人目ニンメ  \n2人目ニンメ  \n3人目ニンメ  \n4人目ニンメ  \n5人目ニンメ  \n6人目ニンメ  \n健康保険扶養ケンコウホケンフヨウ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n税法上の扶養ゼイホウジョウフヨウ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n姓セイ  \n姓(カナ)セイ  \n名メイ  \n名(カナ)メイ  \n生年月日セイネンガッピ  \n性別セイベツ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n続柄ゾクガラ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n同居・別居ドウキョベッキョ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n職業ショクギョウ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n年収ネンシュウ  \n基礎年金番号キソネンキンバンゴウ  \nマイナンバー  \n※健康保険上、税法上の扶養どちらにも該当しない場合、基礎年金番号、マイナンバーの記載は不要です。ケンコウホケンジョウゼイホウジョウフヨウガイトウバアイキソネンキンバンゴウキサイフヨウ  \nまた、未成年者には基礎年金番号はございません。ミセイネンシャキソネンキンバンゴウ  \n<!-- PageBreak -->'), Document(metadata={'Header 1': '入社連絡票(アルバイト)'}, page_content='【社保加入連絡票】シャホカニュウレンラクヒョウ  \n本人ホンニン  \n氏名シメイ  \n姓  \n名  \n性別セイベツ  \n姓(カナ)  \n名(カナ)  \n入社日ニュウシャビ  \n生年月日セイネンガッピ  \n住所ジュウショ  \n郵便番号ユウビンバンゴウ  \n都道府県トドウフケン  \n市区町村シクチョウソン  \n番地バンチ  \nマンション・アパート名メイ  \n市区町村(カナ)シクチョウソン  \n緊急連絡先①キンキュウレンラクサキ  \n氏名シメイ  \n姓  \n名  \n性別セイベツ  \n姓(カナ)  \n名(カナ)  \n住所ジュウショ  \n郵便番号ユウビンバンゴウ  \n都道府県トドウフケン  \n市区町村シクチョウソン  \n番地バンチ  \nマンション・アパート名メイ  \n市区町村(カナ)シクチョウソン  \n電話番号デンワバンゴウ  \nメールアドレス  \n緊急連絡先②キンキュウレンラクサキ  \n氏名シメイ  \n姓  \n名  \n性別セイベツ  \n姓(カナ)  \n名(カナ)  \n住所ジュウショ  \n郵便番号ユウビンバンゴウ  \n都道府県トドウフケン  \n市区町村シクチョウソン  \n番地バンチ  \nマンション・アパート名メイ  \n市区町村(カナ)シクチョウソン  \n電話番号デンワバンゴウ  \nメールアドレス  \n社員区分シャインクブン  \nアルバイト  \n社員コードシャイン  \n電話番号デンワバンゴウ  \n※xxx-xxxx-xxxxの形式でご入力くださいケイシキニュウリョク  \nメールアドレス  \n基礎年金番号キソネンキンバンゴウ  \n※xxxxxxxxxx(ハイフンなし)の形式でご入力くださいケイシキニュウリョク  \n雇用保険番号コヨウホケンバンゴウ  \n※xxxx-xxxxxx-xの形式でご入力くださいケイシキニュウリョク  \n雇用保険番号が不明の場合、前職の社名をご記載ください。コヨウホケンバンゴウフメイバアイゼンショクシャメイキサイ  \nマイナンバー  \n給与キュウヨ  \n基本給キホンキュウ  \n時間給  \n交通費コウツウヒ  \n都度払い  \n他に手当あればご記入くださいタテアテキニュウ  \n契約期間ケイヤクキカン  \n契約期間の定めケイヤクキカンサダ  \nなし  \n有期の場合の期間ユウキバアイキカン  \n～  \n所定労働時間ショテイロウドウジカン  \n1日ニチ  \n8  \n時間ジカン  \n分フン  \n1週間シュウカン  \n40  \n時間ジカン  \n分フン  \n所定労働日数ショテイロウドウニッスウ  \n1ヵ月あたりゲツ  \n日ニチ  \n※特に定めがない場合、ご記載不要です。トクサダバアイキサイフヨウ  \n振込口座フリコミコウザ  \n銀行名ギンコウメイ  \n支店名シテンメイ  \n口座番号コウザバンゴウ  \n主たる給与の  \n受け取り先に該当シュキュウヨウトサキガイトウ  \n選択  \n⇒該当する場合、扶養控除等異動申告書を共有くださいガイトウバアイフヨウコウジョナドイドウシンコクショキョウユウ  \n家族情報カゾクジョウホウ  \n1人目ニンメ  \n2人目ニンメ  \n3人目ニンメ  \n4人目ニンメ  \n5人目ニンメ  \n6人目ニンメ  \n健康保険扶養ケンコウホケンフヨウ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n税法上の扶養ゼイホウジョウフヨウ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n姓セイ  \n姓(カナ)セイ  \n名メイ  \n名(カナ)メイ  \n生年月日セイネンガッピ  \n性別セイベツ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n続柄ゾクガラ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n同居・別居ドウキョベッキョ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n職業ショクギョウ  \n選択  \n選択  \n選択  \n選択  \n選択  \n選択  \n年収ネンシュウ  \n基礎年金番号キソネンキンバンゴウ  \nマイナンバー  \n※健康保険上、税法上の扶養どちらにも該当しない場合、基礎年金番号、マイナンバーの記載は不要です。ケンコウホケンジョウゼイホウジョウフヨウガイトウバアイキソネンキンバンゴウキサイフヨウ  \nまた、未成年者には基礎年金番号はございません。ミセイネンシャキソネンキンバンゴウ')]

# %% [markdown]
# [Document(metadata={'Header 1': 'RAG 開発'}, page_content='部門:AI ソリューション事業部\n名前:青木駿介'), Document(metadata={'Header 1': 'RAG 開発', 'Header 2': '· 導入環境'}, page_content='· Azure portal  \n· VScode  \n· Microsoft account  \n· Azure functions core tools'), Document(metadata={'Header 1': 'RAG 開発', 'Header 2': '· Azure の操作, VSCode の操作'}, page_content='この資料を参考に進めてください。  \ncomputer vision のリソースを作成する必要はありません.  \nその代わり, Azure AI Search を作成する必要があります。  \nAzure AI Search とは、高度な全文検索ができる PaaS であり, RAG を構築する際に利用\nするベクトルストアです。  \nチャンク化されたデータをベクトル化し、検索用に index として保存しておきます。\nまたユーザーからのリクエストに対して、関連のある情報を検索し、抽出します。'), Document(metadata={'Header 1': 'RAG 開発', 'Header 2': '· 技術要素'}, page_content='· Azure AI Document Intelligence  \n· Azure AI Search  \n· Azure OpenAI Service  \n· LangChain  \n<!-- PageBreak -->'), Document(metadata={'Header 1': 'RAG 開発', 'Header 2': '·RAG とは'}, page_content='Retrieval-Augmented Generation の略称で、大規模言語モデルが知らない情報を外部の検\n索システムで検索し、その結果を情報源として回答を生成する手法のことである.  \nメリットとしては、最新かつ信頼度の高い情報にアクセスできること、 ユーザーが情報源\nを参照することができ,生成結果の正確性を確認することができるという点である.  \nユーザーの質問を受けてドキュメントを検索したり,LLM に回答作成の指示を与えたりす\nるモジュールはオーケストレータと言われ,RAG の全体の処理やプロンプトを定義し検索\nシステムや LLM との仲介役になるため、重要な要素になる.'), Document(metadata={'Header 1': 'RAG 開発', 'Header 2': '·RAG とは', 'Header 3': '·チャンク化の種類'}, page_content='https://zenn.dev/sekochan/articles/1786b7198de101  \n1\\. 固定サイズのチャンク:文字数で分ける  \n2\\. 可変サイズのチャンク:  \n特定の文字で区切る,マークダウン言語構造を使用した分割,  \n3\\. 自然言語処理(NLP) ライブラリを使用した分割\n正規表現に基づいたチャンキングなど  \n4\\. 意味で分ける セマンティックチャンキング  \n意味の塊ごとに分けることで、検索の際にピンポイントでヒットし、LLM に必要\nな情報を渡せるようになる。  \nDocument intelligence にこの機能があった. 以下のサイトに詳細が書いてある.  \nAzure AI Document Intelligence を使用した取得拡張生成  \n<!-- PageBreak -->'), Document(metadata={'Header 1': 'RAG 開発', 'Header 2': '·RAG とは', 'Header 3': '·システム構成'}, page_content='システム構成は以下の図のようになっています.  \n<figure>  \nAzure Cognitive\nSearch  \nData Sources  \nSemantic\nchunk  \nExtract  \nIndex  \nPDF  \nQuery ->Knowledge  \nAzure Al Document\nIntelligence  \nDOCX  \nPPTX  \nApp UX  \nApp Server,\nOrchestrator  \nPrompt + Knowledge ->\nResponse  \nXLSX  \nHTML\n</>  \nO  \n9  \nAzure OpenAI\n(GPT/ChatGPT)  \nMD  \nTXT  \n</figure>  \nまた、全体の処理の流れは以下のようになっています.  \n1\\. AI Document Intelligence で PDF を読み取る  \n2\\. PDF の内容を分析し、Markdown として出力する  \n3\\. LangChain の機能を利用し、Markdown の内容を見出し位置(#)#####)でチャン\nク化する  \n4\\. チャンク化した内容をベクトル化し、ベクトルストアである AI Search に登録す\nる  \n5\\. ユーザーからの質問の内容に関連する情報を AI Search から取り出す  \n6\\. Chat に投げる Prompt を構築する  \n7\\. Chat から回答を得る  \n<!-- PageBreak -->'), Document(metadata={'Header 1': '· RAG 精度向上手法概要'}, page_content='今回は Azure Document Intelligence Layout モデルの活用によって実装していきます.  \nAzure Document Intelligence Layout モデルを使ってドキュメントからテキストを抽出し、\nMarkdown 形式での出力を利用してセマンティック·チャンキングを行うように拡張して\nいます。LangChain と MarkdownHeaderTextSplitter を用いて、段落や表に基づいてテキ\nストをチャンクに分割し、意味単位で分割したチャンクを Azure AI Search にベクトルと\nいて保存し、後で RAG パターンで利用できるようにしています。  \nAzure Function 内に、上記のセマンティックチャンキングロジックを含めることで、テキ\nストの分割から API の応答生成までを一貫して行えるようにします。  \n以下のサイトと公式のノートブックを参考に実装を進めていきます。  \n【徹底解説】Document Intelligence を利用して RAG を構築する【セマンティックチャン\nキング】  \nMicrosoft の公式のノートブックはこちら'), Document(metadata={'Header 1': '· 実装手順'}, page_content='1\\. 環境構築  \n2\\. AI Document Intelligence で PDF を読み取り,Markdown 形式で出力する  \n3\\. LangChain の機能を利用し、Markdown の内容を見出し位置(######)でチャン\nク化する  \n4\\. チャンク化した内容をベクトル化し、ベクトルストアである AI Search に登録す\nる  \n5\\. ユーザーからの質問の内容に関連する情報を AI Search から取り出す  \n6\\. Chat に投げる Prompt を構築する  \n7\\. RAG の Chain を構築  \n8\\. Chat から回答を得る  \n<!-- PageBreak -->  \n以下に各手順の詳細な説明を記載する.'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '1. 環境構築'}, page_content='Git hub からクローンしてくることも可能  \ngit clone https://github.com/shun0913suganolab/rag.git  \n以下のコマンドを実行し、必要なパッケージをインストールする'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '1. 環境構築', 'Header 3': 'pip install -r requirements.txt'}, page_content='<table>\n<tr>\n<th>rag &gt;</th>\n<th>= requirements.txt</th>\n</tr>\n<tr>\n<td>1</td>\n<td># DO NOT include azure-functions-worker in this file</td>\n</tr>\n<tr>\n<td>2</td>\n<td># The Python Worker is managed by Azure Functions platform</td>\n</tr>\n<tr>\n<td>3</td>\n<td># Manually managing azure-functions-worker may cause unexpected issues</td>\n</tr>\n<tr>\n<td>4</td>\n<td></td>\n</tr>\n<tr>\n<td>5</td>\n<td>azure-functions</td>\n</tr>\n<tr>\n<td>6</td>\n<td>requests</td>\n</tr>\n<tr>\n<td>7</td>\n<td>openai</td>\n</tr>\n<tr>\n<td>8</td>\n<td>azure-storage-blob</td>\n</tr>\n<tr>\n<td>9</td>\n<td>azure-ai-formrecognizer</td>\n</tr>\n<tr>\n<td>10</td>\n<td>python-dotenv</td>\n</tr>\n<tr>\n<td>11</td>\n<td>langchain</td>\n</tr>\n<tr>\n<td>12</td>\n<td>langchain-community</td>\n</tr>\n<tr>\n<td>13</td>\n<td>langchain-openai</td>\n</tr>\n<tr>\n<td>14</td>\n<td>langchainhub</td>\n</tr>\n<tr>\n<td>15</td>\n<td>tiktoken</td>\n</tr>\n<tr>\n<td>16</td>\n<td>azure-ai-documentintelligence</td>\n</tr>\n<tr>\n<td>17</td>\n<td>azure-identity</td>\n</tr>\n<tr>\n<td>18</td>\n<td>azure-search-documents == 11.6.0b3</td>\n</tr>\n</table>  \n<figure>\n</figure>  \n各自,自身の環境変数を設定する.  \n<!-- PageBreak -->  \n<table>\n<tr>\n<th colspan="4">rag &gt; {} local.settings.json &gt; {}Values</th>\n</tr>\n<tr>\n<th>1</th>\n<th colspan="3" rowspan="2">{ "IsEncrypted": false,</th>\n</tr>\n<tr>\n<th>2</th>\n</tr>\n<tr>\n<td>3</td>\n<td></td>\n<td colspan="2">"Values": E</td>\n</tr>\n<tr>\n<td>4</td>\n<td></td>\n<td colspan="2">"AzureWebJobsStorage": "seDevelopmentStorage=true",</td>\n</tr>\n<tr>\n<td>5</td>\n<td></td>\n<td colspan="2">"FUNCTIONS_WORKER_RUNTIME": "python", ☐</td>\n</tr>\n<tr>\n<td>6</td>\n<td></td>\n<td colspan="2">"COMPUTER_VISION_API_KEY": "0e9d45323e834cd3a0b566ab</td>\n</tr>\n<tr>\n<td>7</td>\n<td></td>\n<td colspan="2">"COMPUTER_VISION_ENDPOINT": "https://cv-rag-dev. cogn ☐</td>\n</tr>\n<tr>\n<td>8</td>\n<td></td>\n<td colspan="2">"AZURE_OPENAI_API_KEY":"a501328d19a04df89960b2c636af</td>\n</tr>\n<tr>\n<td>9</td>\n<td></td>\n<td colspan="2">"AZURE_OPENAI_ENDPOINT":"https://shuns-m2mw0u2v-west</td>\n</tr>\n<tr>\n<td>10</td>\n<td></td>\n<td colspan="2">"AZURE_OPENAI_EMBEDDING_API_KEY":"a501328d19a04df899</td>\n</tr>\n<tr>\n<td>11</td>\n<td></td>\n<td colspan="2">"AZURE_OPENAI_EMBEDDING_ENDPOINT":"https://shuns-m2m</td>\n</tr>\n<tr>\n<td>12</td>\n<td></td>\n<td colspan="2">"DOCUMENT_INTELLIGENCE_API_KEY":"bb4b80af7f3347a38e4</td>\n</tr>\n<tr>\n<td>13</td>\n<td></td>\n<td colspan="2">"DOCUMENT_INTELLIGENCE_ENDPOINT":"https://di-rag-dev</td>\n</tr>\n<tr>\n<td>14</td>\n<td></td>\n<td colspan="2">"AZURE_SEARCH_ENDPOINT": "https://srch-rag-dev-013. se</td>\n</tr>\n<tr>\n<td>15</td>\n<td></td>\n<td colspan="2">"AZURE_SEARCH_ADMIN_KEY": "NOI2T2fDQ2gn3ulIqhz1fFIzJ5</td>\n</tr>\n<tr>\n<td>16</td>\n<td></td>\n<td colspan="2">"AZURE_STORAGE_CONNECTION_STRING":"DefaultEndpointsP</td>\n</tr>\n<tr>\n<td>17</td>\n<td></td>\n<td></td>\n<td>"BLOB_CONTAINER":"container-rag-dev"</td>\n</tr>\n<tr>\n<td>18</td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>19</td>\n<td></td>\n<td></td>\n<td>G</td>\n</tr>\n<tr>\n<td>20</td>\n<td></td>\n<td>}</td>\n<td></td>\n</tr>\n</table>'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '1. 環境構築', 'Header 3': '実装で活用する module を import する'}, page_content='rag  \n2\ndocument_intelligence.py > ...  \n1  \n\\# coding: utf-8  \n2  \n3  \nimport os  \n4\nimport logging  \n5  \nimport ipdb  \n6  \nimport openai  \n7  \nfrom azure.core.credentials import AzureKeyCredential  \n8  \nfrom azure.ai.documentintelligence import DocumentIntelligenceClient  \n9  \nfrom azure.ai.documentintelligence.models import AnalyzeDocumentRequest, AnalyzeResult, ContentFormat  \n10  \n11\nfrom langchain import hub  \n12\nfrom langchain_openai import AzureChatOpenAI  \n13  \nfrom langchain_community.document_loaders import AzureAIDocumentIntelligenceLoader  \n14\nfrom langchain_openai import AzureOpenAIEmbeddings  \n15\nfrom langchain. schema import StrOutputParser  \n16\nfrom langchain. schema.runnable import RunnablePassthrough  \n17  \nfrom langchain. text_splitter import MarkdownHeaderTextSplitter  \n18\nfrom langchain_community.vectorstores import AzureSearch  \n19\nfrom operator import itemgetter  \n20\nfrom langchain. schema.runnable import RunnableMap  \nすべて使用するわけではないが、現状整理できていないためすべて記載している.'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '2. AI Document Intelligence で PDF を読み取り,Markdown 形式で出力する'}, page_content='まずは、PDF を読み込んで Markdown 形式に変換する.  \n今回、対象とする PDF(入力データサンプル.pdf)はストレージアカウントにアッ  \n<!-- PageBreak -->  \nプロードされており,この URL を直接指定してファイルを持ってきている.\nストレージアカウントから URL を指定してファイルを持ってくる際に認証機能に\n関する設定が必要になってくるので、その設定に関しては補足として記載してい\nる.'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '2. AI Document Intelligence で PDF を読み取り,Markdown 形式で出力する', 'Header 3': 'AzureAIDocumentIntelligenceLoader の公式ドキュメント'}, page_content='<figure>  \n\\# Initiate Azure AI Document Intelligence to load the document. You can either specify file_path or url_path\nloader = AzureAIDocumentIntelligenceLoader(url_path=blob_url,  \napi_key = intelligence_key,\napi_endpoint = intelligence_endpoint,\napi_model="prebuilt-layout")  \ndocs = loader. load  \n</figure>'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '3. LangChain の機能を利用し、Markdown の内容を見出し位置(######)でチャン ク化する'}, page_content='次に、Markdown の内容を LangChain の機能を使って分割する.  \n今回は、Markdown の#, ##, ###のタグでチャンキングしている.  \n<figure>  \n\\# Split the document into chunks base on markdown headers.  \nheaders_to_split_on = [\n("#", "Header 1"),\n("##", "Header 2"),\n("###", "Header 3"),\n]\ntext_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)  \ndocs_string = docs[0].page_content\nsplits = text_splitter.split_text(docs_string)\nipdb. set_trace()\nlogging.info(f"Length of splits: {len(splits)}") #Length of splits:34\n\\# [END analyze_documents_output_in_markdown]  \n</figure>  \nipdb というデバッグ用のモジュール(詳細は補足に記載)を使ってブレイクポイント\nを設定し、チャンキングされた内容を出力してみると、以下のように内容ごとにチ\nャンキングされていることがわかる.  \n<!-- PageBreak -->  \n<figure>  \n問題\nデバッグ コンソール\nターミナル\n出力  \n<!-- PageHeader="ポート 6 AZURE コメント" -->  \n[2024-11-08TO9:48:39.434Z] ipdb> Document(metadata={\'Header 1\':\'ABC 株式会社’,‘Header 2\':\'2. 募集売出日程について\'}\npage_content=\'別紙をご参照ください。\')  \nsplits [4]  \n[2024-11-68T09:48:48.095Z] ipdb> Document(metadata={\'Header 1\': \'ABC 株式会社\',\'Header 2\':\'3. 本件募集売出しにおける\n留意事項’,‘Header 3\':\'●配分方針’},page_content=\'目論見書には以下の文面にて配分方針を記載する予定です。 \\n申込みに\n先立ち、2024年7月5日(金)から2024年7月11日(木)までの間で引受人に対して、当該仮条件\\nを参考として需要の申告を行うことが\nできます。当該需要の申告は変更又は撤回することが可能でありま\\nす。販売に当たりましては、東証及び名証の「有価証券上場規\n程」に定める株主数基準の充足、上場後の\\n株式の流通性の確保等を勘案し、需要の申告を行わなかった投資家にも販売が行われる\nことがありま\\nす。 \\n引受人及びその委託販売先金融商品取引業者は、各社の定める配分の基本方針及び社内規則等に従\\nい販売\nを行う方針であります。配分の基本方針については各社の店頭における表示又はホームページに\\nおける表示等をご確認下さい。‘)\nsplits [6]\nI\'  \nsplits [5]  \n[2624-11-08109:49:02.449Z] ipdb> Document(metadata={\'Header 1\': \'ABC 株式会社’,‘Header 2\':\'3. 本件募集売出しにおける\n留意事項\',\'Header 3\':\'●目論見書の使用について\'},page_content=‘本件募集売出しにおける需要調査の実施並びに取得の申込\nみの勧誘にあたり、目論見書を配布いたし\\っます。勧誘にあたっては目論見書をお使いくださいますようお願いいたします。 \\nな\nお、6月 19 日(水)に新株式発行並びに株式売出届出目論見書を引受シ団各社に印刷会社より直送\\nする予定です。 \\nまた、新株\n式発行並びに株式売出届出目論見書の訂正事項分は、仮条件決定日の翌営業日7月4日\\n(木)に1回目を、募集売出価格等決定日7月12\n日(金)に2回目を印刷会社より直送いたします。 \\n上記訂正事項分は、当初の目論見書と合わせて必ず申込期間中に投資家に交付\nしていただきますよう、\\nよろしくお願いいたします。’)  \n[2024-11-08T09:49:24.817Z] ipdb> Document(metadata={\'Header 1\': \'ABC 株式会社\',\'Header 2\':\'●委託販売団への拠出につい\nて\'},page_content=\' <!-- PageNumber="1" -- >\\n <!-- PageBreak -- > \\n本件募集売出しにおいては、2,000 株程度の一般委託販\n売団への拠出を実施する予定です。ただし、当\\n該配分株式数についてはあらかじめ確定することができないため、募集売出価格等\n注定時に需要の状況\\n並びに引受シ団各社の引受責任株数の比率等を勘案した上で拠出していただきますのでご了承ください。‘)  \nsplits [7]  \n[2024-11-08T09:49:31.351Z] ipdb> Document(metadata={\'Header 1\': \'ABC 株式会社’,‘Header 2\':\'●委託販売団への拠出につい\nて’,‘Header 3\':\'●従業員持株会への割当について\'},page_content=\'本件募集売出しにおいては、16,000 株を上限として従業員\n持株会への割当てを実施する予定です。ただ\\nし、当該配分株式数についてはあらかじめ確定することができないため、募集売出価\n格等決定時に需要の\\n状況並びに引受シ団各社の引受責任株数の比率等を勘案した上で拠出していただきますのでご了承くだ\\nさい  \nsplits [8]  \n</figure>  \nSplits はチャンキングされたテキストがリストとして格納されている.  \nMarkdownHeaderTextSplitter の公式ドキュメント'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '4. チャンク化した内容をベクトル化し、ベクトルストアである AI Search に登録す る'}, page_content='次にチャンク化した情報をベクトル化し、ベクトルストアに格納していく. ベクトル\n化を行う方法としては、Azure OpenAI Service の embedding model (chat を行うモ\nデルとは異なるモデル)を活用し、ベクトル化したデータは Azure AI Search に格納\nしていく.  \nEmbedding モデルは"text-embedding-ada-002”という Azure OpenAI の埋め込みモデ\nルを作成して使用する. このモデルを使用するには, Azure OpenAI studio で自身のモ\nデルを"text-embedding-ada-002”に設定してデプロイし,生成したキーやエンドポイン\nトをローカルの環境変数に追記する必要がある.  \nこの処理を行うと、自身で設定したインデックス名のインデックスが Azure 上に作成\nされる.  \nAzureOpenAIEmbeddings の公式ドキュメント  \n<!-- PageBreak -->  \n<!-- PageHeader="Azure OpenAI Embedding の Microsoft 公式" -->  \n<figure>  \n#Azure OpenAIの埋め込みモデルを使用して、テキストの意味的なベクトル表現を生成\naoai_embeddings = AzurannanATEmhaddinge(\nazure_deployment= "text-embedding-ada-002",\nopenai_api_version= 2023-05-15 ,\nopenai_api_key = openai_embedding_key,\nazure_endpoint = openai_embedding_endpoint\n)  \nindex_name: str = "idx-rag-dev" # Azure AI Search上に作成するIndex名\n#Azure Searchのベクトルストアイプスタンスの作成\nvector_store: AzureSearch = AzureSearch(\nazure_search_endpoint=vector_store_address,\nazure_search_key=vector_store_password,\nindex_name=index_name,\nembedding_function=aoai_embeddings . embed_query,\n)  \n\\# 先程チャンク化した情報を格納する  \n\\# 格納するタイミングでベクトル化も行われる  \nvector_store. add_documents (documents=splits)  \nSnipp  \nフクルーン  \n</figure>  \n<figure>  \n三\nMicrosoft Azure  \nア リソース、サービス、ドキュメントの検索(G+/)  \nCopilot  \n☑  \n1  \n幼  \n7  \n习  \nshunsuke.aoki0913@ ...\nINTELLIGENT FORCE (INTE ...  \nホーム >リソース グループ > rg-rag-dev-013 > srch-rag-dev-013  \nsrch-rag-dev-013 | インデックス\n☆  \n×\n☒  \nSearch Service  \n只 検索  \n\\+ インデックスの追加  \n最新の情報に更新  \n削除  \n概要  \n名前でフィルター処理.  \nアクティビティ ログ  \nプタ アクセス制御(IAM)  \n名前  \nドキュメント数  \nベクトル インデックス…  \n合計ストレージ サイズ  \n◆ タグ  \nidx-rag-dev  \n34  \n206.96 KB  \n973.08 KB  \n…  \nX 問題の診断と解決  \n√ 検索管理  \nミニ インデックス  \n¥ロ インデクサー  \nロッ データ ソース  \nエイリアス  \n& スキルセット  \nデバッグ セッション  \n\\> 設定  \n</figure>  \n5\\. ユーザーからの質問の内容に関連する情報を AI Search から取り出す\n次に実際にベクトルストアから、質問に対して関連した情報を抽出します。  \n<!-- PageBreak -->  \n\\# Retrieve relevant chunks based on the question\n\\# 先ほど作成したベクトルストアをRetrieverとして定義\nretriever = vector_store.as_retriever(search_type="similarity")  \nretrieved_docs = retriever. get_relevant_documents (\n"販売分担株数に関して"\n)\n#質問に関連するドキュメントを表示  \nlogging. info(f"retrieved document : {retrieved_docs[0].page_content}")  \nこの時 Retriever というインスタンスを作成して情報を取り出していきます。  \nこの Retriever の振る舞いに関してはこちらの記事で分かりやすくまとまっていたの\nで参照ください。サンプルコードでは SearchType を similarity としているため類似\n検索が行われ、  \nsearch_kwargs を k:3 としているため 3 件の情報が返ってくるよう設定されていま\nす。その後、実際に Retriever に質問を与え、関連する情報を retrieved_docs に格納\nし表示しています。(この引数を設定したままだとエラーが発生する可能性がある.  \n自分はこの引数を設定せずに処理を行った. )  \n出力内容は以下のようになっていて、質問に関連したドキュメントが抽出されている\nことがわかる.  \n<!-- PageBreak -->  \n<figure>  \n80  \nretrieved_docs - retriever.get_relevant_documents(  \n81  \n“販売分担株数に関して”。  \n82\n83  \n2  \n#質問に関連するドキュメントを表示  \nAL  \n出力  \nデバッグ コンソール  \nターミナル  \nポート\n8\nAZURE コメント  \n[2024-11-08T06:33:28.480Z]\n[2024-11-08T06:33:28.480Z]  \n会社の裁量により決定するものといたします。また、販売分担株数の決定においては、個人·法人投資家分と  \n機関投資家分に分けて決定いたします。  \n[2024-11-08106:33:28.480Z]  \n機関投資家分の決定においては、引受シ団各社より報告していただいたディマンドシートに基づき、個別投  \n[2024-11-08T06:33:28.480Z]\n[2024-11-08T06:33:28.481Z]\n[2024-11-08106:33:28.481Z]\n[2024-11-08T06:33:28.481Z]\n[2024-11-08T06:33:28.481Z]  \n資家毎の需要を勘案して決定いたします。そのため、主幹事会社からの販売分担株数の連絡については以下\nのように行います。  \n<!-- PageNumber="2" -- >  \n<!-- PageBreak -- >  \n「責社の販売分担株数は、個人·法人投資家分として〇〇〇株です。また、機関投資  \n[2024-11-08T06:33:28.481Z]  \n家分として○○○株です。その内訳としましてはA銀行〇〇〇株、B生命保険〇〇〇  \n[2024-11-08186:33:28.4817]  \n株,c投資顧問○○○株、–– です。  \n[2024-11-08T06:33:28.481Z]\n[2024-11-08T06:33:28,481Z]  \n従いまして、引受責任株数や「ディマンドシート」へご記入いただいた需要株数と販売分担株数は必ずしもー\n致しませんのであらかじめご了承ください。なお、個別機関投資家への割当株数の変更は慎んでいただきます\nよう、ご協力お願いいたします。  \n[2024-11-08T06:33:28.4817]  \n[2024-11-08T06:33:28.481Z]  \nなお、主幹事会社の裁量にあたっては、原則として以下の点を重視します。  \n[2024-11-08T06:33:28.481Z]  \n1 高い価格帯での需要  \n[2024-11-08106:33:28.481Z]\n[2024-11-08T06:33:28.482Z]\n[2024-11-08T06:33:28.482Z]  \n2 同一価格帯での需要については、提出日の早いもの  \n3 「ディマンドシート」に記入して頂く需要動向等に対するコメント  \n4 需要件数(東京証券取引所スタンダード市場及び名古屋証券取引所メイン市場上場を目的とした株\n主数の増加のため。)  \n[2024-11-08T06:33:28.482Z]  \n[2024-11-08T06:33:28.482Z]  \nまた、上記1~4に加えて、機関投資家への配分については特に以下の点を重視します。  \n[2024-11-08T06:33:28.482Z]  \n5 価格算定能力が高いと推定される、又は長期投資を目的とする投資家からの需要  \n[2024-11-08T06:33:28.482Z]  \n6 運用資産に対する相対的な需要額  \n[2024-11-08T06:33:28.482Z]  \n7 投資資金の性質  \n[2024-11-08T06:33:28.482Z]  \n8 マーケティングへの参加状況  \n[2024-11-08T06:33:28.482Z]  \n9 プレマーケティングのフィードバック内容との整合性  \n[2024-11-08T06:33:28.482Z]  \n上記販売分担株数の割当てにおいては、主幹事会社は、引受シ団各社に対して、オーバーアロットメントに\nよる売出しに関して引受シ団各社が販売を分担することが相当と考えられる株数(以下、「オーバーアロットメン\nト追加取扱株数」という。)を加算して、かかる割当てを行うことがあります。  \n10 具体的な需要状況  \n[2024-11-08106:33:28.482Z]  \n[2024-11-08T06:33:28.482Z]  \n[2024-11-08T06:33:28.482Z]  \n</figure>'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '6. Chat に投げる Prompt を構築する(ここから先はまだ検証中)'}, page_content='LLM に投げかけるプロンプトの内容は非常に重要であり、プロンプトエンジニアリン\nグとしても技術が確立されています。  \nプロンプトエンジニアリングの知識がないユーザーからの質問文をそのままプロンプ\nトとして投げた場合、求める品質の回答が得られない場合があります。そのため、シ\nステム側である程度プロンプトのテンプレートを構築しておき、そこにユーザーから\nの質問を組み込む形を取ります。  \nこの時に利用するのが LangChain の Prompt Template の機能になります。  \nでは実際にソースコードを見てみます。 なお、今回は既に定義された Prompt\nTemplate を利用します。hub から今回は rlm/rag-prompt というテンプレートを pull\nしてきます。テンプレートの中身はこちら  \n<!-- PageBreak -->  \n\\# Use a prompt for RAG that is checked into the LangChain prompt hub (https://smith. langchain. co\nprompt = hub.pull("rlm/rag-prompt")  \n11m = AzureChatOpenAI (\nopenai_api_key = openai.api_key,\nazure_endpoint = openai.azure_endpoint,\nopenai_api_version="2023-05-15", # e.g., "2023-12-01-preview"\nazure_deployment="gpt-35-turbo",\ntemperature=0,\n)  \nデバッグして確認してみると、以下のようになっていることがわかる.  \n<figure>  \nChatPromptTemplate(input_variables=[\'context\', \'question\'], input_types={},\npartial_variables={}, metadata={\'lc_hub_owner\': \'rlm\', \'lc_hub_repo\': \'rag-prompt\',\n\'lc_hub_commit_hash\':\n\'50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e\'},\nmessages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_varia\nbles=[\'context\', \'question\'], input_types={}, partial_variables={}, template="You\nare an assistant for question-answering tasks. Use the following pieces of retrieved\ncontext to answer the question. If you don\'t know the answer, just say that you don\'t\nknow. Use three sentences maximum and keep the answer concise.¥nQuestion:\n{question} ¥nContext: {context} ¥nAnswer:"), additional_kwargs={})])  \n</figure>  \nまた、ここで用いている Azure OpenAI のモデルは先ほどの embedding に用いた\nモデルとは異なるチャット用のモデルである.'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '7. RAG の Chain を構築'}, page_content='Chain とは,LLM や Prompt などのコンポーネントを繋げてシステムを作り上げる\n機能になります。なお Chain を実装するにあたり、LangChain Expression Language\n(LCEL)といった記述方法を利用しています。LLM や Prompt 等のコンポーネント\nを|で繋げるだけで簡単に Chain を構築することが可能です。  \n<!-- PageBreak -->  \n<figure>  \n#取得した関連チャンクを整形し、1つの文字列にまとめる  \ndef format_docs (docs) :\nreturn "\\n\\n" . join(doc.page_content for doc in docs)  \n#RAGの処理チェーン構築\nrag_chain_from_docs = (\n{\n"context": lambda input: format_docs(input["documents"]),\n"question": itemgetter("question"),\n}\nprompt\n11m  \n)\nI\nI\nI\nStrOutputParser()\n)\nrag_chain_with_source = RunnableMap(\n{"documents": retriever, "question": RunnablePassthrough()}\n{\n"documents": lambda input: [doc.metadata for doc in input[ "documents"] ],\n"answer": rag_chain_from_docs,\n}  \n</figure>'), Document(metadata={'Header 1': '· 実装手順', 'Header 2': '8. Chat から回答を得る'}, page_content='最後に、先程組んだ Chain に質問文を与えて実行することで、LLM から回答を得る\nことができます.  \n<figure>  \n\\# Ask a question about the document\nanswer = rag_chain_with_source. invoke(user_question)  \nreturn answer  \n</figure>  \nanswer は LLM から帰ってきた質問に対する答えと、その返答をする際にドキュメ\nントのどの箇所を参考にしたかが辞書になって保存されています  \n<!-- PageBreak -->  \n<figure>\n<figcaption>このように Postman で質問文を json 形式で送ると, LLM からの回答とドキュメ\nントのどこを参照したかが返ってくる.\n☒</figcaption>  \n雪  \nNew Collection / http://localhost:7071/api/function_rag  \n日 保存\n共南  \nPOST\n☒\nhttp://localhost:7071/api/function_rag  \n送信  \nパラメーター 認可 ヘッダー18)  \nスクリプト  \nCookie  \n☐  \n☐\nOGL\n☐\nform-data\n☐\nx-www-form-uriencoded\n☒\nRaw OMATU O GraphQL JSON\n☐  \n整形  \nuser_question": “也充分智株敬の決定方法は?”  \nCookie ヘップ-(4) テスト結果  \n200 OK\n26.61 s\n2.04 KB\nS\nヨコ レスポンスを保存\n\\-  \nRaw\nプレビュー\n可視化  \nJSON\n5  \n6 Q  \n1\n2  \n王  \ndocuments\n1  \n"id": "201kMTcx0T@tMlmMfxYS@@MjZh_WFm\\2utY2@z\\z31/08hZTMu".\n"Heade= 1": "ABC 株式会社”,  \n"Header 2":"委託販売団への搬出について”。  \n"Header 3": "8. 「売分担丼物の決定について"  \n1\\.\nこ\n"id": "MThiNghiMDgtNzwjZ500ZwMzLTg5MDItNOZiYTeSZGNIOWI4",  \n"Header 1": "ABC 株式会社”,\n"Header 2":"*委託販売团への提出について”  \n"Header 3": "8.“来分担株数の決定について"  \n3\\.  \n"id": "vjQwvj@wwwtt/j2m2100ZDU3LTg4zoutY]hunTAwMaFhvams",  \n"Header 1": "ABC 株式会社”,\n"Header 2": "*委託販売印への提出について”。  \n"Header 3": "8.販売分担株数の決定について”  \n1\\.\n成\n"id": "VzMojAzvj@tODcyNCOGNGYwLNEZMOYtMZESNOV]MOU4ZNU5",\n"Header 1": "ABC MICARL",\n"Header 2": "&#8販売印への相出について”。\n"Header 3":"8,販売分担件数の決定について"  \nE  \n"answer"\n“販売分担株融の決定方法は、需要調査による引受シ団全体の需要を読ました上で、主幹事会社の最量により決定されます。選人·法人投資家分と機関投資家分に分けて決定され、機関投資家分の決定には引受シ団各社から報告されたディマンドシートが夢になります。”  \n29  \n1  \n</figure>  \n<!-- PageBreak -->'), Document(metadata={'Header 1': 'フロントエンド実装', 'Header 2': '技術要素'}, page_content='· React  \n· Material UI'), Document(metadata={'Header 1': 'フロントエンド実装', 'Header 2': '技術要素', 'Header 3': 'フロントエンド,バックエンド統合'}, page_content='CORS 設定が必要か確認  \n● ローカル環境でフロントエンドとバックエンドが異なるポートで動作している場\n合、CORS が原因でフロントエンドからリクエストが失敗することがあります。  \n● local.settings.json で以下を設定  \n"Host": {  \n"CORS": "*\'  \n}  \n<figure>  \n三  \n販売分担株数の決定方法は?  \n販売分担株数の決定方法は、需要調査による引受シ団全体の需要を勘案した上で、主幹事会社の裁量により決定されます。個\n人·法人投資家分と機関投資家分に分けて決定され、機関投資家分の決定には引受シ団各社から報告されたディマンドシートが\n基になります。  \n販売分担株数の決定方法は?  \n販売分担株数の決定方法は、需要調査による引受シ団全体の需要を勘案した上で、主幹事会社の裁量により決定されます。個\n人·法人投資家分と機関投資家分に分けて決定され、機関投資家分の決定には引受シ団各社から報告されたディマンドシートが\n基になります。  \nアップロード成功: undefined  \nアップロード成功: undefined  \nファイルを選択  \nメッセージを入力 ...  \n送信  \n</figure>  \n<!-- PageBreak -->'), Document(metadata={'Header 1': 'フロントエンド実装', 'Header 2': '技術要素', 'Header 3': '(補足) Blob から URL を指定してファイルを取り出す'}, page_content='Azure Blob Storage の SAS(Shared Access Signature)トークンを使用すると、ストレー\nジアカウントに保存されている特定のリソース(コンテナやブロブ)へのアクセス権を、\n指定した期間·操作に限定して付与できます。パブリックアクセスが制限されたストレー\nジアカウントであっても、SAS トークンを用いることで、特定の操作を許可する URL を\n生成できるのが特徴です。  \n以下は、SAS トークンを生成し、それを使用してブロブヘアクセスするための詳細な手順\nです。'), Document(metadata={'Header 1': 'フロントエンド実装', 'Header 2': '1. SAS トークンの生成方法'}, page_content='1\\. Azure ポータルにサインインします。  \n2\\. ストレージアカウントに移動し、左側のメニューから「共有アクセス署名\n(SAS)」を選択します。  \n3\\. 次のように SAS の設定を行います:  \n○ 許可するサービス: Blob\n☐  \n<!-- PageBreak -->  \n○ 許可するリソースタイプ: コンテナとオブジェクト  \n○ 許可するアクセス権: 読み取り(ファイルのダウンロードに必要な権限の\nみ付与)  \n○ 開始·終了日時: 必要なアクセス期間  \n○ プロトコル: HTTPS 推奨  \n4\\. 生成ボタンを押して SAS トークンを作成します。  \n5\\. 表示された SAS トークンをコピーします。これが、アクセス URL に付加すること\nで認証に使用されるトークンです。'), Document(metadata={'Header 1': 'フロントエンド実装', 'Header 2': '2. SAS トークン付き URL の構成'}, page_content='SAS トークンは 、? sp=racwdl&st =….. &sig =... 形式のクエリ文字列です。アクセスするブロ\nブの URL にこのトークンを追加することで、認証付きアクセスが可能になります。  \n例えば、次のように URL を構成します。  \nhttps://<ストレージアカウント名>.blob.core.windows.net/<コンテナ名>/<ブロブ名  \n\\> ?< SAS トークソ>  \n<figure>  \n三\nMicrosoft Azure  \nア リソース、サービス、ドキュメントの検索(G+/)  \nI\nCopilot\n2  \nQ  \n快  \n3  \n2  \nshunsuke.aoki0913@.\nINTELLIGENT FORCE  \nホーム > ストレージ アカウント > strag013  \nstrag013  \nShared Access Signature  \n\\>\\>  \n☆\n×\n☒  \nストレージ アカウント  \nP SAS  \n×\n× <<  \n8\nフィードバックの送信  \n√ セキュリティとネットワーク  \nShared Access Signature (SAS) は、Azure Storage リソースに対する制限付きのアクセス権を付与する URI です。ストレージ アカウント キーを渡すことはできないが、特定の\nストレージ アカウントのリソースへのアクセスを委任したいクライアントには Shared Access Signature を提供できます。このようなクライアントに Shared Access Signature URI を\n配布することで、指定した期間にリソースへのアクセスを許可します。  \nShared Access Signature  \nアカウント レベルの SAS では、複数の Storage サービス(BLOB、File、Queue、 Table) へのアクセスを委任できます。ただし、現在、保存されているアクセス ポリシーは、アカウント\nレベルの SAS でサポートされていません。  \nアカウント SAS の作成に関する詳細情報  \n使用できるサービス の  \n☒\nBLOB  \n☒\nファイル  \n☒\nキュー\n☒\nテーブル  \n使用できるリソースの種類 の  \n☐\nサービス\n☒\nコンテナー  \n☒\nオブジェクト  \n与えられているアクセス許可 の  \n☒\n読み取り  \n☒\n書き込み  \n☒\n削除\n☒\nリスト\n☒\n追加\n☒\n作成\n☒\n更新\n☒\nプロセス  \n☒\n不変ストレージ  \n☒\n完全な削除  \nBLOB バージョン管理のアクセス許可 ⊙  \n☒\nバージョンの削除を有効にする  \nhttps://portal.azure.com/#home  \n許可された BLOB インデックスのアクセス許可 ⊙  \n</figure>  \n<!-- PageBreak -->'), Document(metadata={'Header 1': '·(補足) デバッグ用のモジュール ipdb に関して'}, page_content='ipdb は、Python のインタラクティブデバッガ(pdb)を強化したデバッグモジュールで\nす。pdb の基本機能を維持しつつ、さらに便利な機能を追加しているため、より使いやす\nいデバッグ環境を提供します。ipdb は、特に IPython をベースにしているため、より洗\n練されたインターフェースと補完機能を持っています。  \n· IPython の機能を活用:  \n● 補完機能やコマンド履歴(ヒストリー)の保存。  \n● 高度なターミナルインターフェース(カラーリングやハイライト付き)。  \n● IPython の豊富な機能をデバッグ時にも利用可能。  \n· 使いやすいコマンド体系:  \n● pdb のデバッグコマンドをそのまま利用可能。  \n● list、step、next などの標準コマンドに加え、IPython のショートカットを使え\nる。  \n· シームレスなインストール:  \n● Python パッケージ管理システムで簡単にインストール可能。  \nipdb を使用するには、デバッグしたい箇所に以下のようにコードを挿入します:  \nimport ipdb; ipdb.set_trace()  \ndef buggy_function():  \na = 5  \nb=0  \nipdb.set_trace() # デバッグポイントを設定  \nresult = a / b # ここでエラーが発生する  \nreturn result  \n<!-- PageBreak -->'), Document(metadata={'Header 1': '·(補足) デバッグ用のモジュール ipdb に関して', 'Header 2': 'buggy_function()'}, page_content='コード実行時に ipdb.set_trace() が呼び出されると、インタラクティブデバッガが起動し\nます。'), Document(metadata={'Header 1': '参考資料'}, page_content='https://tech-lab.sios.jp/archives/41864\nhttps://tech-lab.sios.jp/archives/43646\nhttps://learn.microsoft.com/en-us/azure/ai-services/document-\nintelligence/concept/retrieval-augmented-generation?view=doc-intel-4.0.0#semantic-\nchunking\nhttps://zenn.dev/sekochan/articles/1786b7198de101')]

# %% [markdown]
# <figure>\n\n<!-- PageHeader="B" -->\n\nBluecad E\n\n</figure>\n\n\n# 問合せ受付Web 詳細設計書\n\n2022年9月23日版\nbluecode株式会社\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="1" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="目次" -->\n\n· サーバ/アカウント情報\n\n· 外部設計\n\n· PC用画面\n\n· スマホ用画面\n\n· 画面のマークアップ\n\n· バリデーションルール(フロントエンド)と表示項目\n\n· 送信ボタン押下時の処理\n\n· スプレッドシートのデータ構造とレイアウト\n\n\n## ● 内部設計\n\n· APIの処理フロー\n\n· API仕様(概要)\n\n· バリデーションルール (バックエンド)と対応\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="2" -->\n<!-- PageBreak -->\n\n\n## サーバ/アカウント情報\n\n\n<table>\n<tr>\n<td rowspan="5">Google スプレッドシート用 (Google Apps Script実行用) Google Drive用</td>\n<td rowspan="2">開発用</td>\n<td>アカウント</td>\n<td>dev@example.local</td>\n<td></td>\n</tr>\n<tr>\n<td>パスワード</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td rowspan="3">本番用 (運用用)</td>\n<td>アカウント</td>\n<td>ope@example.local</td>\n<td></td>\n</tr>\n<tr>\n<td>パスワード</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>認証用 電話番号</td>\n<td>090*</td>\n<td>本番アカウントはMFA必須</td>\n</tr>\n<tr>\n<td></td>\n<td colspan="3"></td>\n<td></td>\n</tr>\n<tr>\n<td rowspan="5">Googleスプレッドシート共有対象 アカウント</td>\n<td colspan="3">ope1@example.local</td>\n<td>パスワードは各自管理</td>\n</tr>\n<tr>\n<td colspan="3">ope2@example.local</td>\n<td>パスワードは各自管理</td>\n</tr>\n<tr>\n<td colspan="2">ope3@example.local</td>\n<td></td>\n<td>パスワードは各自管理</td>\n</tr>\n<tr>\n<td colspan="3">ope4@example.local</td>\n<td>パスワードは各自管理</td>\n</tr>\n<tr>\n<td colspan="3">ope5@example.local</td>\n<td>パスワードは各自管理</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="3" -->\n<!-- PageBreak -->\n\n\n## 外部設計:PC用画面\n\n\n<figure>\n\nTOPページ画面\n\nCONTACTページ画面\n\n相互にリンク\n\nTOP\n\nCONTACT\n\nTOP\n\nCONTACT\n\nお名前\n\nHeader画像\n\nお名前は必須です。\nEmail\n\nEmailは必須かつEmailの形式で入力してください。\nお問合せ内容\n\nsuccess!\n\n会社説明文\n\nお問合せ内容は必須かつ1字以上10字以\n下で入力してください。\n\n送信完了、通信エラーはalertを利用\n\n送信\n\nfooter\n\nfooter\n\n</figure>\n\n最終的な見た目、画面レイアウトは「デザイン」での決定を優先し、ここでは必要な要素、記述などを定義する。\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="4" -->\n<!-- PageBreak -->\n\n\n## 外部設計:スマホ用画面\n\n\n<figure>\n\nTOPページ画面\n\nCONTACTページ画面\n\nWebSite\n\n相互にリンク\n\nWebSite\n\nHome\n\nHome\n\nContact\n\nContact\n\nお問合せ\nお名前\n\nHeader画像\n\nお名前は必須です。\n\nEmail\n\nsuccess!\n\n会社説明文\n\nEmailは必須かつEmailの形式で入力してください。\n\nお問合せ内容\n\n送信完了、通信エラーはalertを利用\n\nお問合せ内容は必須かつ1字以上10字以下で入\nカしてください。\n\n送信\n\n☐\n\n☐\n\n</figure>\n\n最終的な見た目、画面レイアウトは「デザイン」での決定を優先し、ここでは必要な要素、記述などを定義する。\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="5" -->\n<!-- PageBreak -->\n\n\n## 外部設計:画面のマークアップ\n\n\n<table>\n<tr>\n<th>場所</th>\n<th colspan="4">マークアップ(指定のあるもののみ)</th>\n<th>備考</th>\n</tr>\n<tr>\n<td>全ページ共通</td>\n<td>全体 (スマホ対応)</td>\n<td colspan="3">640pxをブレークポイントとしてPC版とモバイル版を切り替え PCファーストでマークアップ</td>\n<td>@media screen and (max-width: 640px) {}</td>\n</tr>\n<tr>\n<td>TOPページ (index.html)</td>\n<td>全体</td>\n<td colspan="3">特に指定無し(デザイナのマークアップに委ねる)</td>\n<td>標準団体の規定に準拠すること SEO対策を意識すること</td>\n</tr>\n<tr>\n<td rowspan="6">CONTACTページ (contact.html)</td>\n<td>全体</td>\n<td colspan="3">特に指定無し(デザイナのマークアップに委ねる)</td>\n<td>標準団体の規定に準拠すること SEO対策を意識すること</td>\n</tr>\n<tr>\n<td rowspan="5">form</td>\n<td>ラベル</td>\n<td>タイプ</td>\n<td>id</td>\n<td>備考</td>\n</tr>\n<tr>\n<td>お名前</td>\n<td>input type="text"</td>\n<td>id="name"</td>\n<td>必須要素。バリデーションルールは別紙に定義</td>\n</tr>\n<tr>\n<td>Email</td>\n<td>input type="email"</td>\n<td>id="email"</td>\n<td>必須要素。バリデーションルールは別紙に定義</td>\n</tr>\n<tr>\n<td>お問合せ内容</td>\n<td>textarea</td>\n<td>id="body"</td>\n<td>必須要素。バリデーションルールは別紙に定義</td>\n</tr>\n<tr>\n<td>送信</td>\n<td>button</td>\n<td>id="submit_btn"</td>\n<td>押下時の動作については別紙に定義</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="6" -->\n<!-- PageBreak -->\n\n\n## 外部設計: バリデーションルール(フロントエンド)と表示項目\n\n\n<table>\n<tr>\n<th>バリデーション場所</th>\n<th>バリデーション対象</th>\n<th colspan="2">ルールおよび表示項目</th>\n<th>備考</th>\n</tr>\n<tr>\n<td rowspan="9">CONTCTページ (contact.html)</td>\n<td rowspan="3">name</td>\n<td>タイミング</td>\n<td>1)submit_btn押下時(keyup時) 2) name keyup時</td>\n<td>条件非マッチならエラー表示 条件マッチならエラー非表示</td>\n</tr>\n<tr>\n<td>ルール</td>\n<td>name == ""</td>\n<td>正規表現を利用せず === との違いを意識する</td>\n</tr>\n<tr>\n<td>エラーメッセージ</td>\n<td>お名前は必須です。</td>\n<td>表示場所、スタイルは画面設計を参照</td>\n</tr>\n<tr>\n<td rowspan="3">email</td>\n<td>タイミング</td>\n<td>1)submit_btn押下時(keyup時) 2) email keyupl</td>\n<td>条件非マッチならエラー表示 条件マッチならエラー非表示</td>\n</tr>\n<tr>\n<td>ルール</td>\n<td>/^[a-z0-9.]+@[a-z0-9.]+¥.[a-z]+$/;</td>\n<td>条件評価には正規表現の利用を想定</td>\n</tr>\n<tr>\n<td>エラーメッセージ</td>\n<td>Emailは必須かつEmailの形式で入力してください。</td>\n<td>表示場所、スタイルは画面設計を参照</td>\n</tr>\n<tr>\n<td rowspan="3">body</td>\n<td>タイミング</td>\n<td>1)submit_btn押下時(keyup時) 2) body keyup時</td>\n<td>条件非マッチならエラー表示 条件マッチならエラー非表示</td>\n</tr>\n<tr>\n<td>ルール</td>\n<td>/^.{1,10}$/;</td>\n<td>条件評価には正規表現の利用を想定</td>\n</tr>\n<tr>\n<td>エラーメッセージ</td>\n<td>お問い合わせ内容は必須かつ1文字以上10文字以下で入力してくだ さい。</td>\n<td>表示場所、スタイルは画面設計を参照</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="7" -->\n<!-- PageBreak -->\n\n\n### 外部設計:送信ボタン押下時のフロント側処理\n\n\n<figure>\n\nname, email, body\n\n再入力\n\n画面\n(ユーザー操作)\n\n項目入力\n\n送信ボタン\n押下\n\nエラー表示\n\nエラー表示\n\nフロントエンド\n\nフロント処理\n(JavaScript)\n\nバリデー\nション\n\nNG\n\nネット\n確認\n\nOK\n\nデータ送信\n\nNG\n\nAPI\n\n値受け取り\n\nバリデー\nション\n\n状況返信\n\nバックエンド\n\nOK\n\n書込み\n\nスプレッドシート\n\nスプレッドシート\n\n</figure>\n\n\n<table>\n<tr>\n<td>フロントエンドバリデーション</td>\n<td>·name, email, bodyの3つの項目が全て条件を満たしているときのみ送信 ·APIに接続できる場合のみ送信(ネットワーク未接続の場合は「Failed to fetch」とalertで表示)</td>\n</tr>\n<tr>\n<td>バックエンドバリデーション</td>\n<td>·name, email, bodyの3つの項目が全て条件を満たしているときのみ送信</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="8" -->\n<!-- PageBreak -->\n\n\n## 外部設計:スプレッドシートのデータ構造およびレイアウト\n\n\n<table>\n<caption>問合せ管理シート データ項目</caption>\n<tr>\n<th>項目名</th>\n<th>データ型※</th>\n<th>初期値</th>\n</tr>\n<tr>\n<td>管理No</td>\n<td>数値</td>\n<td>自動採番 (スプレッドシートの行番号を利用)</td>\n</tr>\n<tr>\n<td>お名前</td>\n<td>文字列</td>\n<td>-</td>\n</tr>\n<tr>\n<td>Email</td>\n<td>文字列</td>\n<td>-</td>\n</tr>\n<tr>\n<td>お問合せ内容</td>\n<td>文字列</td>\n<td>-</td>\n</tr>\n<tr>\n<td>ステータス</td>\n<td>文字列</td>\n<td>受付</td>\n</tr>\n<tr>\n<td>受付日</td>\n<td>文字列</td>\n<td>受付時間</td>\n</tr>\n<tr>\n<td>更新日</td>\n<td>文字列</td>\n<td>受付時間</td>\n</tr>\n</table>\n\n※Googleスプレッドシートではデータ型を強制はできません。\n\n\nGoogleスプレッドシート上のレイアウト\n\n\n<table>\n<tr>\n<th></th>\n<th>A</th>\n<th>B</th>\n<th>C</th>\n<th>D</th>\n<th>E</th>\n<th>F</th>\n</tr>\n<tr>\n<td>1</td>\n<td>お名前</td>\n<td>Email</td>\n<td>お問合せ内容</td>\n<td>ステータス</td>\n<td>受付日</td>\n<td>更新日</td>\n</tr>\n<tr>\n<td>2</td>\n<td>お名前</td>\n<td>Email</td>\n<td>お問合せ内容</td>\n<td>ステータス</td>\n<td>受付日</td>\n<td>更新日</td>\n</tr>\n</table>\n\n\n1行目を見出し行とする\n自動採番される行番号を管理Noとする(実運用では難あり)\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="9" -->\n<!-- PageBreak -->\n\n\n### 内部設計:送信ボタン押下時のAPI側処理\n\n\n<figure>\n\nname, email, body\n\n再入力\n\n画面\n(ユーザー操作)\n\n項目入力\n\n送信ボタン\n押下\n\nエラー表示\n\nエラー表示\n\nフロントエンド\n\nフロント処理\n(JavaScript)\n\nバリデー\nション\n\nネット\n確認\n\nNG\n\nOK\n\nデータ送信\n\nNG\n\nAPI\n\n値受け取り\n\nバリデー\nション\n\n状況返信\n\nバックエンド\n\nOK\n\n書込み\n\nスプレッドシート\n\nスプレッドシート\n\n</figure>\n\n\n<table>\n<tr>\n<td>フロントエンドバリデーション</td>\n<td>·name, email, bodyの3つの項目が全て条件を満たしているときのみ送信 ·APIに接続できる場合のみ送信(ネットワーク未接続の場合は「Failed to fetch」とalertで表示)</td>\n</tr>\n<tr>\n<td>バックエンドバリデーション</td>\n<td>·name, email, bodyの3つの項目が全て条件を満たしているときのみ送信</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="10" -->\n<!-- PageBreak -->\n\n\n# 内部設計:API仕様(概要)\n\n\n<table>\n<tr>\n<td>機能概要</td>\n<td>·contact.htmlのformから送信されたname, email, bodyをPOSTにて受け取る ·受け取った値のバリデーションを行う ·バリデーションNGの場合は、その旨JSON形式でレスポンス ·バリデーションOKの場合は、Googleスプレッドシートに値を書き込み、完了をJSONでレスポンス</td>\n</tr>\n<tr>\n<td rowspan="2">リクエスト</td>\n<td>URL ·デプロイ時に動的に生成されるURLを利用 ■認証 ·なし(本番運用ではありません。普通はオレオレJWTとかOIDCとか使います) ■引数 · name, email, body</td>\n</tr>\n<tr>\n<td>■形式 · POST (content-type:application/x-www-form-urlencoded)</td>\n</tr>\n<tr>\n<td rowspan="3">処理</td>\n<td>■バリデーションOK時 (バリデーションルールは別紙) ·受け取ったname, email, bodyをレイアウトに基づきGoogleスプレッドシードの最終行に格納 ·その際、ステータス(初期値=受付)、受付日時も同じ行に格納</td>\n</tr>\n<tr>\n<td>■バリデーションNG時</td>\n</tr>\n<tr>\n<td>·エラーレスポンスを返す</td>\n</tr>\n<tr>\n<td rowspan="3">レスポンス</td>\n<td>■成功時</td>\n</tr>\n<tr>\n<td>{message: "success!"}</td>\n</tr>\n<tr>\n<td>■エラー時 {message: "validation error!"}</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="11" -->\n<!-- PageBreak -->\n\n\n## 内部設計: バリデーションルール(バックエンド)と対応\n\n\n<table>\n<tr>\n<th>バリデーション場所</th>\n<th>バリデーション対象</th>\n<th colspan="2">ルールおよび表示項目</th>\n<th>備考</th>\n</tr>\n<tr>\n<td rowspan="9">CONTCTページ (contact.html)</td>\n<td rowspan="3">name</td>\n<td>タイミング</td>\n<td>データ受取時(スプレッドシートへの書込み前)</td>\n<td>条件非マッチならエラーレスポンス 条件マッチならエラー処理継続</td>\n</tr>\n<tr>\n<td>ルール</td>\n<td>name == ""</td>\n<td>正規表現を利用せず === との違いを意識する</td>\n</tr>\n<tr>\n<td>対応</td>\n<td>validation errorレスポンス返却</td>\n<td>{ message: "validation error!" }</td>\n</tr>\n<tr>\n<td rowspan="3">email</td>\n<td>タイミング</td>\n<td>データ受取時(スプレッドシートへの書込み前)</td>\n<td>条件非マッチならエラーレスポンス 条件マッチならエラー処理継続</td>\n</tr>\n<tr>\n<td>ルール</td>\n<td>/^[a-z0-9.]+@[a-z0-9.]+¥.[a-z]+$/;</td>\n<td>条件評価には正規表現の利用を想定</td>\n</tr>\n<tr>\n<td>対応</td>\n<td>validation errorレスポンス返却</td>\n<td>{ message: "validation error!" }</td>\n</tr>\n<tr>\n<td rowspan="3">body</td>\n<td>タイミング</td>\n<td>データ受取時(スプレッドシートへの書込み前)</td>\n<td>条件非マッチならエラーレスポンス 条件マッチならエラー処理継続</td>\n</tr>\n<tr>\n<td>ルール</td>\n<td>/^.{1,10}$/;</td>\n<td>条件評価には正規表現の利用を想定</td>\n</tr>\n<tr>\n<td>対応</td>\n<td>validation errorレスポンス返却</td>\n<td>{ message: "validation error!" }</td>\n</tr>\n</table>\n\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="12" -->\n<!-- PageBreak -->\n\n\n<figure>\n\n<!-- PageHeader="B" -->\n<!-- PageHeader="Bluecad E" -->\n\n</figure>\n\n\n## 参考資料\n\n<!-- PageFooter="bluecode inc." -->\n<!-- PageNumber="13" -->\n'

# %% [markdown]
# '問合せ受付Web\n\n詳細設計書\n\n2022年9月23日版\n\nbluecode株式会社\n\nbluecode inc.\n\n<!-- PageBreak -->\n\n目次\n\nサーバ/アカウント情報\n\n外部設計\n\nPC用画面\n\nスマホ用画面\n\n画面のマークアップ\n\nバリデーションルール（フロントエンド）と表示項目\n\n送信ボタン押下時の処理\n\nスプレッドシートのデータ構造とレイアウト\n\n内部設計\n\nAPIの処理フロー\n\nAPI仕様（概要）\n\nバリデーションルール（バックエンド）と対応\n\nbluecode inc.\n\n<!-- PageBreak -->\n\nサーバ/アカウント情報\n\nbluecode inc.\n\nGoogle スプレッドシート用\n\n（Google Apps Script実行用）\n\nGoogle Drive用\n\n開発用\n\nアカウント\n\nパスワード\n\n本番用\n\n（運用用）\n\nアカウント\n\nパスワード\n\ndev@example.local\n\n*******\n\nope@example.local\n\n*******\n\nGoogleスプレッドシート共有対象\n\nアカウント\n\nope1@example.local\n\nope2@example.local\n\nope3@example.local\n\nope4@example.local\n\nope5@example.local\n\nパスワードは各自管理\n\nパスワードは各自管理\n\nパスワードは各自管理\n\nパスワードは各自管理\n\nパスワードは各自管理\n\n090********\n\n本番アカウントはMFA必須\n\n認証用\n\n電話番号\n\n<!-- PageBreak -->\n\n外部設計：PC用画面\n\nbluecode inc.\n\nTOP\n\nCONTACT\n\nHeader画像\n\nfooter\n\n会社說明文\n\nTOP\n\nCONTACT\n\nfooter\n\nお名前\n\nEmail\n\nお問合せ内容\n\n送信\n\nお名前は必須です。\n\nEmailは必須かつEmailの形式で入力してください。\n\nお問合せ内容は必須かつ1字以上10字以下で入力してください。\n\nTOPページ画面\n\nCONTACTページ画面\n\n最終的な見た目、画面レイアウトは「デザイン」での決定を優先し、ここでは必要な要素、記述などを定義する。\n\n相互にリンク\n\nsuccess!\n\n送信完了、通信エラーはalertを利用\n\n<!-- PageBreak -->\n\n外部設計：スマホ用画面\n\nbluecode inc.\n\nTOPページ画面\n\nCONTACTページ画面\n\nWebSite\n\nHome\n\nContact\n\nHeader画像\n\n会社說明文\n\nWebSite\n\nHome\n\nContact\n\nお問合せ\n\nお名前\n\nEmail\n\nお問合せ内容\n\nお名前は必須です。\n\nEmailは必須かつEmailの形式で入力してください。\n\nお問合せ内容は必須かつ1字以上10字以下で入力してください。\n\n送信\n\n相互にリンク\n\n最終的な見た目、画面レイアウトは「デザイン」での決定を優先し、ここでは必要な要素、記述などを定義する。\n\nsuccess!\n\n送信完了、通信エラーはalertを利用\n\n<!-- PageBreak -->\n\n外部設計：画面のマークアップ\n\nbluecode inc.\n\nTOPページ\n\n(index.html)\n\n場所\n\nCONTACTページ\n\n(contact.html)\n\n特に指定無し（デザイナのマークアップに委ねる）\n\nマークアップ（指定のあるもののみ）\n\n標準団体の規定に準拠すること\n\nSEO対策を意識すること\n\n備考\n\n全体\n\n特に指定無し（デザイナのマークアップに委ねる）\n\n標準団体の規定に準拠すること\n\nSEO対策を意識すること\n\n全体\n\nform\n\nラベル\n\nタイプ\n\nid\n\n備考\n\nお名前\n\ninput type=“text”\n\nid=“name”\n\n必須要素。バリデーションルールは別紙に定義\n\nEmail\n\ninput type=“email”\n\nid=“email”\n\n必須要素。バリデーションルールは別紙に定義\n\nお問合せ内容\n\ntextarea\n\nid=“body”\n\n必須要素。バリデーションルールは別紙に定義\n\n送信\n\nbutton\n\nid=“submit_btn”\n\n押下時の動作については別紙に定義\n\n全ページ共通\n\n640pxをブレークポイントとしてPC版とモバイル版を切り替え\n\nPCファーストでマークアップ\n\n@media screen and (max-width: 640px) {}\n\n全体\n\n（スマホ対応）\n\n<!-- PageBreak -->\n\n外部設計：バリデーションルール（フロントエンド）と表示項目\n\nbluecode inc.\n\nCONTCTページ\n\n(contact.html)\n\nバリデーション場所\n\nname\n\nバリデーション対象\n\nタイミング\n\nルール\n\nエラーメッセージ\n\n１）submit_btn押下時（keyup時)\n\n２）name keyup時\n\nname==“”\n\nお名前は必須です。\n\nルールおよび表示項目\n\n備考\n\n条件非マッチならエラー表示\n\n条件マッチならエラー非表示\n\n正規表現を利用せず\n\n===との違いを意識する\n\n表示場所、スタイルは画面設計を参照\n\nemail\n\nタイミング\n\nルール\n\nエラーメッセージ\n\n１）submit_btn押下時（keyup時)\n\n２）email keyup時\n\n/^[a-z0-9.]+@[a-z0-9.]+\\\\.[a-z]+$/;\n\nEmailは必須かつEmailの形式で入力してください。\n\n条件非マッチならエラー表示\n\n条件マッチならエラー非表示\n\n条件評価には正規表現の利用を想定\n\n表示場所、スタイルは画面設計を参照\n\nbody\n\nタイミング\n\nルール\n\nエラーメッセージ\n\n１）submit_btn押下時（keyup時)\n\n２）body keyup時\n\n/^.{1,10}$/;\n\nお問い合わせ内容は必須かつ1文字以上10文字以下で入力してください。\n\n条件非マッチならエラー表示\n\n条件マッチならエラー非表示\n\n条件評価には正規表現の利用を想定\n\n表示場所、スタイルは画面設計を参照\n\n<!-- PageBreak -->\n\n外部設計：送信ボタン押下時のフロント側処理\n\nbluecode inc.\n\n画面\n\n（ユーザー操作）\n\nフロント処理\n\n（JavaScript）\n\nAPI\n\nスプレッドシート\n\nフロントエンド\n\nバックエンド\n\nスプレッドシート\n\nバリデーション\n\n項目入力\n\n送信ボタン\n\n押下\n\nエラー表示\n\n値受け取り\n\nバリデーション\n\nエラー表示\n\n状況返信\n\nname, email, body\n\n再入力\n\nOK\n\nデータ送信\n\nNG\n\nOK\n\n書込み\n\nフロントエンドバリデーション\n\n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信\n\n・APIに接続できる場合のみ送信（ネットワーク未接続の場合は「Failed to fetch」とalertで表示）\n\nバックエンドバリデーション\n\n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信\n\nネット\n\n確認\n\nNG\n\n<!-- PageBreak -->\n\n外部設計：スプレッドシートのデータ構造およびレイアウト\n\nbluecode inc.\n\n項目名\n\nデータ型※\n\n初期値\n\n管理No\n\n数値\n\n自動採番\n\n(スプレッドシートの行番号を利用）\n\nお名前\n\n文字列\n\n\\-\n\nEmail\n\n文字列\n\n\\-\n\nお問合せ内容\n\n文字列\n\n\\-\n\nステータス\n\n文字列\n\n受付\n\n受付日\n\n文字列\n\n受付時間\n\n問合せ管理シート データ項目\n\n※Googleスプレッドシートではデータ型を強制はできません。\n\n1\n\nお名前\n\nEmail\n\nお問合せ内容\n\nステータス\n\nGoogleスプレッドシート上のレイアウト\n\nA\n\nB\n\nC\n\nD\n\n2\n\nお名前\n\nEmail\n\nお問合せ内容\n\nステータス\n\n受付日\n\nE\n\n受付日\n\n1行目を見出し行とする\n\n自動採番される行番号を管理Noとする（実運用では難あり）\n\n更新日\n\nF\n\n更新日\n\n更新日\n\n文字列\n\n受付時間\n\n※Googleスプレッドシートではデータ型を強制はできません。\n\n<!-- PageBreak -->\n\n内部設計：送信ボタン押下時のAPI側処理\n\nbluecode inc.\n\n画面\n\n（ユーザー操作）\n\nフロント処理\n\n（JavaScript）\n\nAPI\n\nスプレッドシート\n\nフロントエンド\n\nバックエンド\n\nスプレッドシート\n\nバリデーション\n\n項目入力\n\n送信ボタン\n\n押下\n\nエラー表示\n\n値受け取り\n\nバリデーション\n\nエラー表示\n\n状況返信\n\nname, email, body\n\n再入力\n\nOK\n\nデータ送信\n\nNG\n\nNG\n\nOK\n\n書込み\n\nフロントエンドバリデーション\n\n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信\n\n・APIに接続できる場合のみ送信（ネットワーク未接続の場合は「Failed to fetch」とalertで表示）\n\nバックエンドバリデーション\n\n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信\n\nネット\n\n確認\n\n<!-- PageBreak -->\n\n内部設計： API仕様（概要）\n\nbluecode inc.\n\n機能概要\n\n・contact.htmlのformから送信されたname, email, bodyをPOSTにて受け取る\n\n・受け取った値のバリデーションを行う\n\n・バリデーションNGの場合は、その旨JSON形式でレスポンス\n\n・バリデーションOKの場合は、Googleスプレッドシートに値を書き込み、完了をJSONでレスポンス\n\nリクエスト\n\n■URL\n\n・デプロイ時に動的に生成されるURLを利用\n\n■認証\n\n・なし（本番運用ではありません。普通はオレオレJWTとかOIDCとか使います）\n\n■引数\n\n・name, email, body\n\n■形式\n\n・POST（content-type:application/x-www-form-urlencoded)\n\nレスポンス\n\n■成功時\n\n{message: “success!”}\n\n■エラー時\n\n{message: “validation error!”}\n\n処理\n\n■バリデーションOK時（バリデーションルールは別紙）\n\n・受け取ったname, email, bodyをレイアウトに基づきGoogleスプレッドシードの最終行に格納\n\n・その際、ステータス（初期値=受付）、受付日時も同じ行に格納\n\n■バリデーションNG時\n\n・エラーレスポンスを返す\n\n<!-- PageBreak -->\n\n内部設計：バリデーションルール（バックエンド）と対応\n\nbluecode inc.\n\nCONTCTページ\n\n(contact.html)\n\nバリデーション場所\n\nname\n\nバリデーション対象\n\nタイミング\n\nルール\n\n対応\n\nデータ受取時（スプレッドシートへの書込み前）\n\nname==“”\n\nvalidation errorレスポンス返却\n\nルールおよび表示項目\n\n備考\n\n条件非マッチならエラーレスポンス\n\n条件マッチならエラー処理継続\n\n正規表現を利用せず\n\n===との違いを意識する\n\n{ message: "validation error!" }\n\nemail\n\nタイミング\n\nルール\n\n対応\n\nデータ受取時（スプレッドシートへの書込み前）\n\n/^[a-z0-9.]+@[a-z0-9.]+\\\\.[a-z]+$/;\n\nvalidation errorレスポンス返却\n\n条件非マッチならエラーレスポンス\n\n条件マッチならエラー処理継続\n\n条件評価には正規表現の利用を想定\n\n{ message: "validation error!" }\n\nbody\n\nタイミング\n\nルール\n\n対応\n\nデータ受取時（スプレッドシートへの書込み前）\n\n/^.{1,10}$/;\n\nvalidation errorレスポンス返却\n\n条件非マッチならエラーレスポンス\n\n条件マッチならエラー処理継続\n\n条件評価には正規表現の利用を想定\n\n{ message: "validation error!" }\n\n<!-- PageBreak -->\n\n参考資料\n\nbluecode inc.\n'

# %% [markdown]
#  [Document(metadata={}, page_content='問合せ受付Web  \n詳細設計書  \n2022年9月23日版  \nbluecode株式会社  \nbluecode inc.  \n<!-- PageBreak -->  \n目次  \nサーバ/アカウント情報  \n外部設計  \nPC用画面  \nスマホ用画面  \n画面のマークアップ  \nバリデーションルール（フロントエンド）と表示項目  \n送信ボタン押下時の処理  \nスプレッドシートのデータ構造とレイアウト  \n内部設計  \nAPIの処理フロー  \nAPI仕様（概要）  \nバリデーションルール（バックエンド）と対応  \nbluecode inc.  \n<!-- PageBreak -->  \nサーバ/アカウント情報  \nbluecode inc.  \nGoogle スプレッドシート用  \n（Google Apps Script実行用）  \nGoogle Drive用  \n開発用  \nアカウント  \nパスワード  \n本番用  \n（運用用）  \nアカウント  \nパスワード  \ndev@example.local  \n*******  \nope@example.local  \n*******  \nGoogleスプレッドシート共有対象  \nアカウント  \nope1@example.local  \nope2@example.local  \nope3@example.local  \nope4@example.local  \nope5@example.local  \nパスワードは各自管理  \nパスワードは各自管理  \nパスワードは各自管理  \nパスワードは各自管理  \nパスワードは各自管理  \n090********  \n本番アカウントはMFA必須  \n認証用  \n電話番号  \n<!-- PageBreak -->  \n外部設計：PC用画面  \nbluecode inc.  \nTOP  \nCONTACT  \nHeader画像  \nfooter  \n会社說明文  \nTOP  \nCONTACT  \nfooter  \nお名前  \nEmail  \nお問合せ内容  \n送信  \nお名前は必須です。  \nEmailは必須かつEmailの形式で入力してください。  \nお問合せ内容は必須かつ1字以上10字以下で入力してください。  \nTOPページ画面  \nCONTACTページ画面  \n最終的な見た目、画面レイアウトは「デザイン」での決定を優先し、ここでは必要な要素、記述などを定義する。  \n相互にリンク  \nsuccess!  \n送信完了、通信エラーはalertを利用  \n<!-- PageBreak -->  \n外部設計：スマホ用画面  \nbluecode inc.  \nTOPページ画面  \nCONTACTページ画面  \nWebSite  \nHome  \nContact  \nHeader画像  \n会社說明文  \nWebSite  \nHome  \nContact  \nお問合せ  \nお名前  \nEmail  \nお問合せ内容  \nお名前は必須です。  \nEmailは必須かつEmailの形式で入力してください。  \nお問合せ内容は必須かつ1字以上10字以下で入力してください。  \n送信  \n相互にリンク  \n最終的な見た目、画面レイアウトは「デザイン」での決定を優先し、ここでは必要な要素、記述などを定義する。  \nsuccess!  \n送信完了、通信エラーはalertを利用  \n<!-- PageBreak -->  \n外部設計：画面のマークアップ  \nbluecode inc.  \nTOPページ  \n(index.html)  \n場所  \nCONTACTページ  \n(contact.html)  \n特に指定無し（デザイナのマークアップに委ねる）  \nマークアップ（指定のあるもののみ）  \n標準団体の規定に準拠すること  \nSEO対策を意識すること  \n備考  \n全体  \n特に指定無し（デザイナのマークアップに委ねる）  \n標準団体の規定に準拠すること  \nSEO対策を意識すること  \n全体  \nform  \nラベル  \nタイプ  \nid  \n備考  \nお名前  \ninput type=“text”  \nid=“name”  \n必須要素。バリデーションルールは別紙に定義  \nEmail  \ninput type=“email”  \nid=“email”  \n必須要素。バリデーションルールは別紙に定義  \nお問合せ内容  \ntextarea  \nid=“body”  \n必須要素。バリデーションルールは別紙に定義  \n送信  \nbutton  \nid=“submit_btn”  \n押下時の動作については別紙に定義  \n全ページ共通  \n640pxをブレークポイントとしてPC版とモバイル版を切り替え  \nPCファーストでマークアップ  \n@media screen and (max-width: 640px) {}  \n全体  \n（スマホ対応）  \n<!-- PageBreak -->  \n外部設計：バリデーションルール（フロントエンド）と表示項目  \nbluecode inc.  \nCONTCTページ  \n(contact.html)  \nバリデーション場所  \nname  \nバリデーション対象  \nタイミング  \nルール  \nエラーメッセージ  \n１）submit_btn押下時（keyup時)  \n２）name keyup時  \nname==“”  \nお名前は必須です。  \nルールおよび表示項目  \n備考  \n条件非マッチならエラー表示  \n条件マッチならエラー非表示  \n正規表現を利用せず  \n===との違いを意識する  \n表示場所、スタイルは画面設計を参照  \nemail  \nタイミング  \nルール  \nエラーメッセージ  \n１）submit_btn押下時（keyup時)  \n２）email keyup時  \n/^[a-z0-9.]+@[a-z0-9.]+\\\\.[a-z]+$/;  \nEmailは必須かつEmailの形式で入力してください。  \n条件非マッチならエラー表示  \n条件マッチならエラー非表示  \n条件評価には正規表現の利用を想定  \n表示場所、スタイルは画面設計を参照  \nbody  \nタイミング  \nルール  \nエラーメッセージ  \n１）submit_btn押下時（keyup時)  \n２）body keyup時  \n/^.{1,10}$/;  \nお問い合わせ内容は必須かつ1文字以上10文字以下で入力してください。  \n条件非マッチならエラー表示  \n条件マッチならエラー非表示  \n条件評価には正規表現の利用を想定  \n表示場所、スタイルは画面設計を参照  \n<!-- PageBreak -->  \n外部設計：送信ボタン押下時のフロント側処理  \nbluecode inc.  \n画面  \n（ユーザー操作）  \nフロント処理  \n（JavaScript）  \nAPI  \nスプレッドシート  \nフロントエンド  \nバックエンド  \nスプレッドシート  \nバリデーション  \n項目入力  \n送信ボタン  \n押下  \nエラー表示  \n値受け取り  \nバリデーション  \nエラー表示  \n状況返信  \nname, email, body  \n再入力  \nOK  \nデータ送信  \nNG  \nOK  \n書込み  \nフロントエンドバリデーション  \n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信  \n・APIに接続できる場合のみ送信（ネットワーク未接続の場合は「Failed to fetch」とalertで表示）  \nバックエンドバリデーション  \n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信  \nネット  \n確認  \nNG  \n<!-- PageBreak -->  \n外部設計：スプレッドシートのデータ構造およびレイアウト  \nbluecode inc.  \n項目名  \nデータ型※  \n初期値  \n管理No  \n数値  \n自動採番  \n(スプレッドシートの行番号を利用）  \nお名前  \n文字列  \n\\-  \nEmail  \n文字列  \n\\-  \nお問合せ内容  \n文字列  \n\\-  \nステータス  \n文字列  \n受付  \n受付日  \n文字列  \n受付時間  \n問合せ管理シート データ項目  \n※Googleスプレッドシートではデータ型を強制はできません。  \n1  \nお名前  \nEmail  \nお問合せ内容  \nステータス  \nGoogleスプレッドシート上のレイアウト  \nA  \nB  \nC  \nD  \n2  \nお名前  \nEmail  \nお問合せ内容  \nステータス  \n受付日  \nE  \n受付日  \n1行目を見出し行とする  \n自動採番される行番号を管理Noとする（実運用では難あり）  \n更新日  \nF  \n更新日  \n更新日  \n文字列  \n受付時間  \n※Googleスプレッドシートではデータ型を強制はできません。  \n<!-- PageBreak -->  \n内部設計：送信ボタン押下時のAPI側処理  \nbluecode inc.  \n画面  \n（ユーザー操作）  \nフロント処理  \n（JavaScript）  \nAPI  \nスプレッドシート  \nフロントエンド  \nバックエンド  \nスプレッドシート  \nバリデーション  \n項目入力  \n送信ボタン  \n押下  \nエラー表示  \n値受け取り  \nバリデーション  \nエラー表示  \n状況返信  \nname, email, body  \n再入力  \nOK  \nデータ送信  \nNG  \nNG  \nOK  \n書込み  \nフロントエンドバリデーション  \n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信  \n・APIに接続できる場合のみ送信（ネットワーク未接続の場合は「Failed to fetch」とalertで表示）  \nバックエンドバリデーション  \n・name, email, bodyの3つの項目が全て条件を満たしているときのみ送信  \nネット  \n確認  \n<!-- PageBreak -->  \n内部設計： API仕様（概要）  \nbluecode inc.  \n機能概要  \n・contact.htmlのformから送信されたname, email, bodyをPOSTにて受け取る  \n・受け取った値のバリデーションを行う  \n・バリデーションNGの場合は、その旨JSON形式でレスポンス  \n・バリデーションOKの場合は、Googleスプレッドシートに値を書き込み、完了をJSONでレスポンス  \nリクエスト  \n■URL  \n・デプロイ時に動的に生成されるURLを利用  \n■認証  \n・なし（本番運用ではありません。普通はオレオレJWTとかOIDCとか使います）  \n■引数  \n・name, email, body  \n■形式  \n・POST（content-type:application/x-www-form-urlencoded)  \nレスポンス  \n■成功時  \n{message: “success!”}  \n■エラー時  \n{message: “validation error!”}  \n処理  \n■バリデーションOK時（バリデーションルールは別紙）  \n・受け取ったname, email, bodyをレイアウトに基づきGoogleスプレッドシードの最終行に格納  \n・その際、ステータス（初期値=受付）、受付日時も同じ行に格納  \n■バリデーションNG時  \n・エラーレスポンスを返す  \n<!-- PageBreak -->  \n内部設計：バリデーションルール（バックエンド）と対応  \nbluecode inc.  \nCONTCTページ  \n(contact.html)  \nバリデーション場所  \nname  \nバリデーション対象  \nタイミング  \nルール  \n対応  \nデータ受取時（スプレッドシートへの書込み前）  \nname==“”  \nvalidation errorレスポンス返却  \nルールおよび表示項目  \n備考  \n条件非マッチならエラーレスポンス  \n条件マッチならエラー処理継続  \n正規表現を利用せず  \n===との違いを意識する  \n{ message: "validation error!" }  \nemail  \nタイミング  \nルール  \n対応  \nデータ受取時（スプレッドシートへの書込み前）  \n/^[a-z0-9.]+@[a-z0-9.]+\\\\.[a-z]+$/;  \nvalidation errorレスポンス返却  \n条件非マッチならエラーレスポンス  \n条件マッチならエラー処理継続  \n条件評価には正規表現の利用を想定  \n{ message: "validation error!" }  \nbody  \nタイミング  \nルール  \n対応  \nデータ受取時（スプレッドシートへの書込み前）  \n/^.{1,10}$/;  \nvalidation errorレスポンス返却  \n条件非マッチならエラーレスポンス  \n条件マッチならエラー処理継続  \n条件評価には正規表現の利用を想定  \n{ message: "validation error!" }  \n<!-- PageBreak -->  \n参考資料  \nbluecode inc.')]
